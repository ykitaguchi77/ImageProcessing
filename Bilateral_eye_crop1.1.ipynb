# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/ImageProcessing/blob/master/Bilateral_eye_crop1.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #顔の画像から目を検出して切り抜くスクリプト
# ・Haarcascade_eyeを使用<br>
# ・目が検出できないものはskipする<br>
# ・検出された目周囲の画像を縦横とも1.1倍の幅で切り抜く(2つ検出したときには2つの検出範囲の上端と下端を基準とする）<br>
# ・切り取った画像を250px*250pxにresizeする<br>
# ・対応表をCSV形式で出力（連番、左右、元フォルダ、元画像名）

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import copy
import pandas as pd
import csv
from random import randint
from time import sleep
import math
import sys

import glob
import random
from PIL import Image
# %matplotlib inline

#サポートパッチのインポート
from google.colab.patches import cv2_imshow
import cv2

plt.ion()   # interactive mode

# %% [markdown]
# #Google colabをマウント

# %%
from google.colab import drive
drive.mount('/content/drive')

# !date -R
# !unzip -qq drive/My\ Drive/Deep_learning/gravcont_original.zip
# !date -R
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Mon, 17 Feb 2020 09:29:19 +0000
# Mon, 17 Feb 2020 09:29:31 +0000
# cont  drive  grav  sample_data

# %%
#元画像フォルダ
in_path = '/content/grav'

#保存先フォルダ
out_path = '/content/drive/My Drive/Deep_learning/gravcont_processed/grav_processed'

#CSVファイルのフォルダ
csv_path = '/content/drive/My Drive/Deep_learning/gravcont_processed/grav_error.csv'

# %% [markdown]
# #Haarcascadeを指定

# %%
# カスケードファイルのパス
eye_cascade_path = '/content/drive/My Drive/Deep_learning/haarcascade_eye.xml'

# カスケード分類器の特徴量取得
eye_cascade = cv2.CascadeClassifier(eye_cascade_path)

# %% [markdown]
# #処理するdirectoryの設定
# （画像が多い時には複数回に分ける）

# %%
#処理するDirectoryの設定
file = os.listdir(in_path)
print(len(file))

#ここにフォルダ番号を記載する (ex. [0:999])
processing_file = file[0:321]
print(processing_file)
len(processing_file)
# Out:
# 321
# ['6989.jpg', '1429.jpg', '129.jpg', '3128.jpg', '6320.jpg', '489.JPG', '3695.JPG', '1682.jpg', '7798.jpg', '1304.jpg', '3077.jpg', '2182.JPG', '5490.jpg', '3956.JPG', '3646.jpg', '6432.JPG', '6518.jpg', '374.jpg', '2658.jpg', '1786.JPG', '2630.jpg', '5333.jpg', '818.jpg', '7443.JPG', '1879.jpg', '7552.JPG', '385.jpg', '2407.JPG', '5692.jpg', '1910.JPG', '3484.jpg', '6147.jpg', '4822.jpg', '1020.jpg', '1088.jpg', '5021.JPG', '2974.JPG', '6663.jpg', '1553.jpg', '1453.jpg', '2436.JPG', '425.jpg', '1347.jpg', '8168.JPG', '2189.JPG', '3144.jpg', '2853.jpg', '4272.jpg', '4186.JPG', '2042.jpg', '1995.jpg', '7049.jpg', '3609.JPG', '4921.JPG', '2765.JPG', '5323.JPG', '1231.JPG', '36.jpg', '1528.JPG', '3176.jpg', '5865.JPG', '1457.jpg', '4997.JPG', '5758.jpg', '2736.jpg', '6662.jpg', '1597.JPG', '2960.jpg', '2803.jpg', '4805.jpg', '2321.jpg', '6150.jpg', '57.jpg', '3444.jpg', '4939.JPG', '3496.JPG', '1037.jpg', '4930.JPG', '7455.JPG', '4233.JPG', '5095.JPG', '2885.JPG', '1041.JPG', '3802.jpg', '5838.JPG', '7900.jpg', '3331.JPG', '4588.jpg', '6725.JPG', '6513.JPG', '4030.jpg', '7397.JPG', '5647.jpg', '5378.jpg', '7449.JPG', '533.jpg', '2900.jpg', '4331.jpg', '4606.jpg', '3502.jpg', '6788.JPG', '1501.JPG', '2794.jpg', '4486.jpg', '5681.jpg', '5763.JPG', '7681.JPG', '1313.JPG', '1357.jpg', '6654.jpg', '7025.jpg', '5070.JPG', '5571.JPG', '7161.jpg', '5237.JPG', '1508.jpg', '7781.JPG', '611.jpg', '2644.jpg', '2941.jpg', '1729.JPG', '4628.JPG', '4710.JPG', '8079.JPG', '7302.JPG', '6297.jpg', '180.jpg', '5541.jpg', '2307.jpg', '950.JPG', '3276.JPG', '2222.JPG', '5965.JPG', '1396.jpg', '4292.jpg', '8184.JPG', '5989.JPG', '7879.JPG', '3412.JPG', '4008.jpg', '5586.jpg', '5290.JPG', '5890.jpg', '2670.JPG', '3079.JPG', '6855.jpg', '1931.jpg', '1446.JPG', '555.JPG', '5913.jpg', '3056.JPG', '155.jpg', '2510.jpg', '2851.jpg', '782.JPG', '19.jpg', '429.jpg', '1525.jpg', '3918.jpg', '724.JPG', '6599.jpg', '4958.jpg', '1259.JPG', '4125.jpg', '718.jpg', '3843.JPG', '8198.jpg', '3164.jpg', '1385.jpg', '3714.jpg', '5551.jpg', '1773.JPG', '7644.JPG', '7800.JPG', '6355.JPG', '8105.jpg', '3217.JPG', '5260.jpg', '3146.JPG', '7987.JPG', '5901.jpg', '5888.JPG', '5550.jpg', '1483.jpg', '6806.jpg', '507.JPG', '4206.jpg', '5203.JPG', '7870.jpg', '6555.jpg', '1815.JPG', '4382.jpg', '63.jpg', '4993.JPG', '6478.jpg', '7419.JPG', '977.JPG', '965.JPG', '2762.JPG', '2801.jpg', '7436.jpg', '5015.jpg', '2976.jpg', '1370.JPG', '2523.JPG', '6707.JPG', '3875.JPG', '7867.jpg', '7669.JPG', '1309.JPG', '3532.JPG', '7534.JPG', '893.jpg', '957.JPG', '4759.JPG', '502.jpg', '7765.jpg', '6489.JPG', '3162.jpg', '6502.JPG', '4388.JPG', '4480.JPG', '5607.JPG', '2007.JPG', '7349.jpg', '3528.jpg', '5125.jpg', '7166.JPG', '7346.JPG', '1524.jpg', '7403.JPG', '6579.jpg', '17.jpg', '3472.jpg', '6283.JPG', '7763.jpg', '5297.JPG', '6764.jpg', '1503.jpg', '2684.jpg', '1978.jpg', '6298.JPG', '465.jpg', '7709.jpg', '2370.jpg', '5546.jpg', '5673.jpg', '5582.JPG', '1438.jpg', '7527.JPG', '1333.JPG', '1284.jpg', '4069.jpg', '787.JPG', '6003.jpg', '24.jpg', '4540.JPG', '2557.JPG', '4618.JPG', '5426.JPG', '3568.jpg', '3752.JPG', '4236.jpg', '4813.JPG', '122.jpg', '2231.jpg', '2709.jpg', '7936.jpg', '4881.JPG', '534.jpg', '4465.jpg', '7745.JPG', '5768.jpg', '7283.jpg', '1841.jpg', '5540.jpg', '426.JPG', '7291.jpg', '4209.JPG', '6074.JPG', '1664.JPG', '2203.jpg', '1432.JPG', '7507.jpg', '3942.JPG', '2508.jpg', '4577.JPG', '3809.jpg', '7874.JPG', '4713.jpg', '5543.JPG', '3600.jpg', '3684.jpg', '5646.JPG', '5906.jpg', '2837.jpg', '6269.jpg', '6965.jpg', '876.jpg', '1764.JPG', '3418.jpg', '3264.JPG', '5880.JPG', '1001.jpg', '6486.JPG', '5273.JPG', '2218.jpg', '5299.jpg', '983.JPG', '5069.jpg', '1270.jpg', '6553.jpg', '4874.jpg', '466.jpg', '3046.jpg', '2148.jpg', '3352.jpg', '3237.JPG', '1378.JPG', '2689.jpg', '1336.JPG']
# 321

# %% [markdown]
# #画像切り抜き
# 大きい辺を1辺とする正方形に整形する

# %%
def expand2square(pil_img, background_color):
    width, height = pil_img.size
    if width == height:
        return pil_img
    elif width > height:
        result = Image.new(pil_img.mode, (width, width), background_color)
        result.paste(pil_img, (0, (width-height)//2))
        return result
    else:
        result = Image.new(pil_img.mode, (height, height), background_color)
        result.paste(pil_img, (0, (height - width) // 2))
        return result

# %%
#処理時間の計測
start = time.time()

l=0
detection_error = []
for i in processing_file:
      l+=1
      print('')
      print(str(l))
      print(str(i))
      print('image path = '+ in_path + '/' + i)

      #OPEN CVで画像を読み込み
      img = cv2.imread(in_path + '/' + i) 
      
      # 画像グレースケール化
      grayscale_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

      #100pix以上のもので目に見えるものを抽出
      eye_list = eye_cascade.detectMultiScale(grayscale_img, minSize=(300, 300))
                    
      # 眼検出判定
      if len(eye_list) >= 1:
          print('目が' + str(len(eye_list)) +'個検出されました')
          if len(eye_list) > 2:
              detection_error.append(i) #3つ以上検出時には、画像処理は行うがerrorリストには加える
        
      elif len(eye_list) == 0:
          print("eye detection error")
          detection_error.append(i)
      
      #画像の切り抜きと保存
      if len(eye_list) >= 1:              
          ex_min, ey_min, ex_ew_max, ey_eh_max = 100000, 100000, 0, 0  #初期値を設定
          m=0
          for (ex, ey, ew, eh) in eye_list:
              m+=1
              #右眼の外上端、左眼の外下端の座標を取得
              ex_min, ey_min, ex_ew_max, ey_eh_max = min(ex_min, ex), min(ey_min, ey), max(ex_ew_max, ex+ew), max(ey_eh_max, ey+eh)
              #print(ex_min, ey_min, ex_ew_max, ey_eh_max)
          img = Image.open(in_path + '/' + i)

          #横はイメージの幅に合わせて、縦は検出された目の縦幅の1.2倍の幅で切り抜く。その後に横辺250pixに縮小する
          #img_cropped = img.crop((int(ex_min), int(ey_min), int(ex_ew_max), int(ey_eh_max))) 
          img_cropped = img.crop((0, int(1.2*ey_min-0.2*ey_eh_max), img.width, int(-0.2*ey_min+1.2*ey_eh_max))) 
          img_new = expand2square(img_cropped, (0, 0, 0)).resize((250, 250))
          
          #切り取った画像を表示
          #plt.imshow(np.asarray(img_new))
          #plt.show()

          #ランダムな位置で224pixに切り取る
          #x, y = random.randint(0,27), random.randint(0,27) 
          #img_randcrop = img_resized[y: y+223, x: x+223]
          
          #保存する際のよくわからないエラーをskipする

      elif len(eye_list) == 0: #眼が検出されない場合は切り抜きを行わず画像を保存する
          img = Image.open(in_path + '/' + i)
          img_new = expand2square(img_cropped, (0, 0, 0)).resize((250, 250))

      '''
      k=0
      while True:
          try:
              img_new.save(out_path +'/'+ str(i))
              print(out_path +'/'+ str(i))
          except:
              k+=1
              time.sleep(1)
              if k==3:
                  print('Save error!')
                  sys.exit()
      '''

print('Process done!!')
elapsed_time = time.time() - start
print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")
print ("detection error:")
print (detection_error)
# Out:
# 1
# 6989.jpg
# image path = /content/grav/6989.jpg
# 目が2個検出されました
#
# 2
# 1429.jpg
# image path = /content/grav/1429.jpg
# 目が2個検出されました
#
# 3
# 129.jpg
# image path = /content/grav/129.jpg
# 目が2個検出されました
#
# 4
# 3128.jpg
# image path = /content/grav/3128.jpg
# 目が2個検出されました
#
# 5
# 6320.jpg
# image path = /content/grav/6320.jpg
# 目が2個検出されました
#
# 6
# 489.JPG
# image path = /content/grav/489.JPG
# 目が2個検出されました
#
# 7
# 3695.JPG
# image path = /content/grav/3695.JPG
# 目が2個検出されました
#
# 8
# 1682.jpg
# image path = /content/grav/1682.jpg
# eye detection error
#
# 9
# 7798.jpg
# image path = /content/grav/7798.jpg
# 目が2個検出されました
#
# 10
# 1304.jpg
# image path = /content/grav/1304.jpg
# 目が2個検出されました
#
# 11
# 3077.jpg
# image path = /content/grav/3077.jpg
# 目が2個検出されました
#
# 12
# 2182.JPG
# image path = /content/grav/2182.JPG
# 目が2個検出されました
#
# 13
# 5490.jpg
# image path = /content/grav/5490.jpg
# 目が2個検出されました
#
# 14
# 3956.JPG
# image path = /content/grav/3956.JPG
# 目が2個検出されました
#
# 15
# 3646.jpg
# image path = /content/grav/3646.jpg
# 目が2個検出されました
#
# 16
# 6432.JPG
# image path = /content/grav/6432.JPG
# 目が2個検出されました
#
# 17
# 6518.jpg
# image path = /content/grav/6518.jpg
# 目が2個検出されました
#
# 18
# 374.jpg
# image path = /content/grav/374.jpg
# 目が2個検出されました
#
# 19
# 2658.jpg
# image path = /content/grav/2658.jpg
# 目が2個検出されました
#
# 20
# 1786.JPG
# image path = /content/grav/1786.JPG
# 目が2個検出されました
#
# 21
# 2630.jpg
# image path = /content/grav/2630.jpg
# 目が2個検出されました
#
# 22
# 5333.jpg
# image path = /content/grav/5333.jpg
# 目が2個検出されました
#
# 23
# 818.jpg
# image path = /content/grav/818.jpg
# 目が2個検出されました
#
# 24
# 7443.JPG
# image path = /content/grav/7443.JPG
# 目が2個検出されました
#
# 25
# 1879.jpg
# image path = /content/grav/1879.jpg
# 目が1個検出されました
#
# 26
# 7552.JPG
# image path = /content/grav/7552.JPG
# 目が2個検出されました
#
# 27
# 385.jpg
# image path = /content/grav/385.jpg
# 目が2個検出されました
#
# 28
# 2407.JPG
# image path = /content/grav/2407.JPG
# 目が2個検出されました
#
# 29
# 5692.jpg
# image path = /content/grav/5692.jpg
# 目が2個検出されました
#
# 30
# 1910.JPG
# image path = /content/grav/1910.JPG
# 目が2個検出されました
#
# 31
# 3484.jpg
# image path = /content/grav/3484.jpg
# 目が2個検出されました
#
# 32
# 6147.jpg
# image path = /content/grav/6147.jpg
# 目が2個検出されました
#
# 33
# 4822.jpg
# image path = /content/grav/4822.jpg
# 目が2個検出されました
#
# 34
# 1020.jpg
# image path = /content/grav/1020.jpg
# 目が2個検出されました
#
# 35
# 1088.jpg
# image path = /content/grav/1088.jpg
# 目が2個検出されました
#
# 36
# 5021.JPG
# image path = /content/grav/5021.JPG
# 目が2個検出されました
#
# 37
# 2974.JPG
# image path = /content/grav/2974.JPG
# 目が2個検出されました
#
# 38
# 6663.jpg
# image path = /content/grav/6663.jpg
# eye detection error
#
# 39
# 1553.jpg
# image path = /content/grav/1553.jpg
# 目が2個検出されました
#
# 40
# 1453.jpg
# image path = /content/grav/1453.jpg
# 目が2個検出されました
#
# 41
# 2436.JPG
# image path = /content/grav/2436.JPG
# 目が2個検出されました
#
# 42
# 425.jpg
# image path = /content/grav/425.jpg
# 目が2個検出されました
#
# 43
# 1347.jpg
# image path = /content/grav/1347.jpg
# 目が2個検出されました
#
# 44
# 8168.JPG
# image path = /content/grav/8168.JPG
# 目が2個検出されました
#
# 45
# 2189.JPG
# image path = /content/grav/2189.JPG
# 目が2個検出されました
#
# 46
# 3144.jpg
# image path = /content/grav/3144.jpg
# 目が4個検出されました
#
# 47
# 2853.jpg
# image path = /content/grav/2853.jpg
# 目が2個検出されました
#
# 48
# 4272.jpg
# image path = /content/grav/4272.jpg
# 目が2個検出されました
#
# 49
# 4186.JPG
# image path = /content/grav/4186.JPG
# 目が2個検出されました
#
# 50
# 2042.jpg
# image path = /content/grav/2042.jpg
# 目が2個検出されました
#
# 51
# 1995.jpg
# image path = /content/grav/1995.jpg
# 目が2個検出されました
#
# 52
# 7049.jpg
# image path = /content/grav/7049.jpg
# 目が2個検出されました
#
# 53
# 3609.JPG
# image path = /content/grav/3609.JPG
# 目が2個検出されました
#
# 54
# 4921.JPG
# image path = /content/grav/4921.JPG
# 目が2個検出されました
#
# 55
# 2765.JPG
# image path = /content/grav/2765.JPG
# 目が2個検出されました
#
# 56
# 5323.JPG
# image path = /content/grav/5323.JPG
# 目が2個検出されました
#
# 57
# 1231.JPG
# image path = /content/grav/1231.JPG
# 目が2個検出されました
#
# 58
# 36.jpg
# image path = /content/grav/36.jpg
# 目が2個検出されました
#
# 59
# 1528.JPG
# image path = /content/grav/1528.JPG
# 目が2個検出されました
#
# 60
# 3176.jpg
# image path = /content/grav/3176.jpg
# eye detection error
#
# 61
# 5865.JPG
# image path = /content/grav/5865.JPG
# 目が1個検出されました
#
# 62
# 1457.jpg
# image path = /content/grav/1457.jpg
# 目が2個検出されました
#
# 63
# 4997.JPG
# image path = /content/grav/4997.JPG
# 目が2個検出されました
#
# 64
# 5758.jpg
# image path = /content/grav/5758.jpg
# 目が1個検出されました
#
# 65
# 2736.jpg
# image path = /content/grav/2736.jpg
# 目が2個検出されました
#
# 66
# 6662.jpg
# image path = /content/grav/6662.jpg
# 目が2個検出されました
#
# 67
# 1597.JPG
# image path = /content/grav/1597.JPG
# 目が2個検出されました
#
# 68
# 2960.jpg
# image path = /content/grav/2960.jpg
# 目が2個検出されました
#
# 69
# 2803.jpg
# image path = /content/grav/2803.jpg
# 目が2個検出されました
#
# 70
# 4805.jpg
# image path = /content/grav/4805.jpg
# 目が2個検出されました
#
# 71
# 2321.jpg
# image path = /content/grav/2321.jpg
# 目が2個検出されました
#
# 72
# 6150.jpg
# image path = /content/grav/6150.jpg
# 目が2個検出されました
#
# 73
# 57.jpg
# image path = /content/grav/57.jpg
# 目が2個検出されました
#
# 74
# 3444.jpg
# image path = /content/grav/3444.jpg
# 目が2個検出されました
#
# 75
# 4939.JPG
# image path = /content/grav/4939.JPG
# 目が2個検出されました
#
# 76
# 3496.JPG
# image path = /content/grav/3496.JPG
# 目が2個検出されました
#
# 77
# 1037.jpg
# image path = /content/grav/1037.jpg
# 目が2個検出されました
#
# 78
# 4930.JPG
# image path = /content/grav/4930.JPG
# 目が1個検出されました
#
# 79
# 7455.JPG
# image path = /content/grav/7455.JPG
# 目が2個検出されました
#
# 80
# 4233.JPG
# image path = /content/grav/4233.JPG
# 目が2個検出されました
#
# 81
# 5095.JPG
# image path = /content/grav/5095.JPG
# 目が3個検出されました
#
# 82
# 2885.JPG
# image path = /content/grav/2885.JPG
# 目が2個検出されました
#
# 83
# 1041.JPG
# image path = /content/grav/1041.JPG
# 目が2個検出されました
#
# 84
# 3802.jpg
# image path = /content/grav/3802.jpg
# 目が2個検出されました
#
# 85
# 5838.JPG
# image path = /content/grav/5838.JPG
# 目が2個検出されました
#
# 86
# 7900.jpg
# image path = /content/grav/7900.jpg
# 目が2個検出されました
#
# 87
# 3331.JPG
# image path = /content/grav/3331.JPG
# 目が2個検出されました
#
# 88
# 4588.jpg
# image path = /content/grav/4588.jpg
# 目が2個検出されました
#
# 89
# 6725.JPG
# image path = /content/grav/6725.JPG
# 目が2個検出されました
#
# 90
# 6513.JPG
# image path = /content/grav/6513.JPG
# 目が2個検出されました
#
# 91
# 4030.jpg
# image path = /content/grav/4030.jpg
# 目が2個検出されました
#
# 92
# 7397.JPG
# image path = /content/grav/7397.JPG
# 目が2個検出されました
#
# 93
# 5647.jpg
# image path = /content/grav/5647.jpg
# 目が2個検出されました
#
# 94
# 5378.jpg
# image path = /content/grav/5378.jpg
# 目が2個検出されました
#
# 95
# 7449.JPG
# image path = /content/grav/7449.JPG
# 目が2個検出されました
#
# 96
# 533.jpg
# image path = /content/grav/533.jpg
# 目が1個検出されました
#
# 97
# 2900.jpg
# image path = /content/grav/2900.jpg
# 目が2個検出されました
#
# 98
# 4331.jpg
# image path = /content/grav/4331.jpg
# 目が1個検出されました
#
# 99
# 4606.jpg
# image path = /content/grav/4606.jpg
# 目が2個検出されました
#
# 100
# 3502.jpg
# image path = /content/grav/3502.jpg
# 目が2個検出されました
#
# 101
# 6788.JPG
# image path = /content/grav/6788.JPG
# 目が2個検出されました
#
# 102
# 1501.JPG
# image path = /content/grav/1501.JPG
# 目が2個検出されました
#
# 103
# 2794.jpg
# image path = /content/grav/2794.jpg
# 目が2個検出されました
#
# 104
# 4486.jpg
# image path = /content/grav/4486.jpg
# 目が1個検出されました
#
# 105
# 5681.jpg
# image path = /content/grav/5681.jpg
# 目が2個検出されました
#
# 106
# 5763.JPG
# image path = /content/grav/5763.JPG
# 目が2個検出されました
#
# 107
# 7681.JPG
# image path = /content/grav/7681.JPG
# 目が2個検出されました
#
# 108
# 1313.JPG
# image path = /content/grav/1313.JPG
# 目が2個検出されました
#
# 109
# 1357.jpg
# image path = /content/grav/1357.jpg
# 目が2個検出されました
#
# 110
# 6654.jpg
# image path = /content/grav/6654.jpg
# 目が2個検出されました
#
# 111
# 7025.jpg
# image path = /content/grav/7025.jpg
# eye detection error
#
# 112
# 5070.JPG
# image path = /content/grav/5070.JPG
# 目が2個検出されました
#
# 113
# 5571.JPG
# image path = /content/grav/5571.JPG
# 目が2個検出されました
#
# 114
# 7161.jpg
# image path = /content/grav/7161.jpg
# 目が2個検出されました
#
# 115
# 5237.JPG
# image path = /content/grav/5237.JPG
# 目が2個検出されました
#
# 116
# 1508.jpg
# image path = /content/grav/1508.jpg
# eye detection error
#
# 117
# 7781.JPG
# image path = /content/grav/7781.JPG
# 目が2個検出されました
#
# 118
# 611.jpg
# image path = /content/grav/611.jpg
# 目が2個検出されました
#
# 119
# 2644.jpg
# image path = /content/grav/2644.jpg
# 目が2個検出されました
#
# 120
# 2941.jpg
# image path = /content/grav/2941.jpg
# 目が2個検出されました
#
# 121
# 1729.JPG
# image path = /content/grav/1729.JPG
# 目が2個検出されました
#
# 122
# 4628.JPG
# image path = /content/grav/4628.JPG
# 目が2個検出されました
#
# 123
# 4710.JPG
# image path = /content/grav/4710.JPG
# 目が2個検出されました
#
# 124
# 8079.JPG
# image path = /content/grav/8079.JPG
# 目が2個検出されました
#
# 125
# 7302.JPG
# image path = /content/grav/7302.JPG
# 目が2個検出されました
#
# 126
# 6297.jpg
# image path = /content/grav/6297.jpg
# 目が2個検出されました
#
# 127
# 180.jpg
# image path = /content/grav/180.jpg
# 目が2個検出されました
#
# 128
# 5541.jpg
# image path = /content/grav/5541.jpg
# 目が2個検出されました
#
# 129
# 2307.jpg
# image path = /content/grav/2307.jpg
# 目が2個検出されました
#
# 130
# 950.JPG
# image path = /content/grav/950.JPG
# 目が2個検出されました
#
# 131
# 3276.JPG
# image path = /content/grav/3276.JPG
# 目が2個検出されました
#
# 132
# 2222.JPG
# image path = /content/grav/2222.JPG
# 目が2個検出されました
#
# 133
# 5965.JPG
# image path = /content/grav/5965.JPG
# 目が2個検出されました
#
# 134
# 1396.jpg
# image path = /content/grav/1396.jpg
# eye detection error
#
# 135
# 4292.jpg
# image path = /content/grav/4292.jpg
# eye detection error
#
# 136
# 8184.JPG
# image path = /content/grav/8184.JPG
# 目が1個検出されました
#
# 137
# 5989.JPG
# image path = /content/grav/5989.JPG
# 目が2個検出されました
#
# 138
# 7879.JPG
# image path = /content/grav/7879.JPG
# 目が2個検出されました
#
# 139
# 3412.JPG
# image path = /content/grav/3412.JPG
# 目が2個検出されました
#
# 140
# 4008.jpg
# image path = /content/grav/4008.jpg
# 目が2個検出されました
#
# 141
# 5586.jpg
# image path = /content/grav/5586.jpg
# 目が2個検出されました
#
# 142
# 5290.JPG
# image path = /content/grav/5290.JPG
# 目が2個検出されました
#
# 143
# 5890.jpg
# image path = /content/grav/5890.jpg
# 目が1個検出されました
#
# 144
# 2670.JPG
# image path = /content/grav/2670.JPG
# 目が2個検出されました
#
# 145
# 3079.JPG
# image path = /content/grav/3079.JPG
# 目が2個検出されました
#
# 146
# 6855.jpg
# image path = /content/grav/6855.jpg
# 目が2個検出されました
#
# 147
# 1931.jpg
# image path = /content/grav/1931.jpg
# 目が2個検出されました
#
# 148
# 1446.JPG
# image path = /content/grav/1446.JPG
# 目が2個検出されました
#
# 149
# 555.JPG
# image path = /content/grav/555.JPG
# 目が2個検出されました
#
# 150
# 5913.jpg
# image path = /content/grav/5913.jpg
# 目が2個検出されました
#
# 151
# 3056.JPG
# image path = /content/grav/3056.JPG
# 目が2個検出されました
#
# 152
# 155.jpg
# image path = /content/grav/155.jpg
# 目が3個検出されました
#
# 153
# 2510.jpg
# image path = /content/grav/2510.jpg
# 目が2個検出されました
#
# 154
# 2851.jpg
# image path = /content/grav/2851.jpg
# 目が2個検出されました
#
# 155
# 782.JPG
# image path = /content/grav/782.JPG
# 目が2個検出されました
#
# 156
# 19.jpg
# image path = /content/grav/19.jpg
# 目が2個検出されました
#
# 157
# 429.jpg
# image path = /content/grav/429.jpg
# 目が2個検出されました
#
# 158
# 1525.jpg
# image path = /content/grav/1525.jpg
# 目が2個検出されました
#
# 159
# 3918.jpg
# image path = /content/grav/3918.jpg
# 目が1個検出されました
#
# 160
# 724.JPG
# image path = /content/grav/724.JPG
# 目が2個検出されました
#
# 161
# 6599.jpg
# image path = /content/grav/6599.jpg
# 目が2個検出されました
#
# 162
# 4958.jpg
# image path = /content/grav/4958.jpg
# 目が2個検出されました
#
# 163
# 1259.JPG
# image path = /content/grav/1259.JPG
# 目が2個検出されました
#
# 164
# 4125.jpg
# image path = /content/grav/4125.jpg
# 目が2個検出されました
#
# 165
# 718.jpg
# image path = /content/grav/718.jpg
# 目が2個検出されました
#
# 166
# 3843.JPG
# image path = /content/grav/3843.JPG
# 目が2個検出されました
#
# 167
# 8198.jpg
# image path = /content/grav/8198.jpg
# 目が2個検出されました
#
# 168
# 3164.jpg
# image path = /content/grav/3164.jpg
# 目が2個検出されました
#
# 169
# 1385.jpg
# image path = /content/grav/1385.jpg
# 目が2個検出されました
#
# 170
# 3714.jpg
# image path = /content/grav/3714.jpg
# 目が2個検出されました
#
# 171
# 5551.jpg
# image path = /content/grav/5551.jpg
# 目が2個検出されました
#
# 172
# 1773.JPG
# image path = /content/grav/1773.JPG
# 目が2個検出されました
#
# 173
# 7644.JPG
# image path = /content/grav/7644.JPG
# 目が2個検出されました
#
# 174
# 7800.JPG
# image path = /content/grav/7800.JPG
# 目が2個検出されました
#
# 175
# 6355.JPG
# image path = /content/grav/6355.JPG
# 目が2個検出されました
#
# 176
# 8105.jpg
# image path = /content/grav/8105.jpg
# 目が2個検出されました
#
# 177
# 3217.JPG
# image path = /content/grav/3217.JPG
# 目が2個検出されました
#
# 178
# 5260.jpg
# image path = /content/grav/5260.jpg
# 目が2個検出されました
#
# 179
# 3146.JPG
# image path = /content/grav/3146.JPG
# 目が2個検出されました
#
# 180
# 7987.JPG
# image path = /content/grav/7987.JPG
# 目が2個検出されました
#
# 181
# 5901.jpg
# image path = /content/grav/5901.jpg
# 目が2個検出されました
#
# 182
# 5888.JPG
# image path = /content/grav/5888.JPG
# 目が2個検出されました
#
# 183
# 5550.jpg
# image path = /content/grav/5550.jpg
# 目が2個検出されました
#
# 184
# 1483.jpg
# image path = /content/grav/1483.jpg
# 目が2個検出されました
#
# 185
# 6806.jpg
# image path = /content/grav/6806.jpg
# 目が2個検出されました
#
# 186
# 507.JPG
# image path = /content/grav/507.JPG
# 目が2個検出されました
#
# 187
# 4206.jpg
# image path = /content/grav/4206.jpg
# 目が2個検出されました
#
# 188
# 5203.JPG
# image path = /content/grav/5203.JPG
# 目が2個検出されました
#
# 189
# 7870.jpg
# image path = /content/grav/7870.jpg
# 目が2個検出されました
#
# 190
# 6555.jpg
# image path = /content/grav/6555.jpg
# 目が2個検出されました
#
# 191
# 1815.JPG
# image path = /content/grav/1815.JPG
# 目が1個検出されました
#
# 192
# 4382.jpg
# image path = /content/grav/4382.jpg
# 目が2個検出されました
#
# 193
# 63.jpg
# image path = /content/grav/63.jpg
# 目が2個検出されました
#
# 194
# 4993.JPG
# image path = /content/grav/4993.JPG
# 目が2個検出されました
#
# 195
# 6478.jpg
# image path = /content/grav/6478.jpg
# 目が2個検出されました
#
# 196
# 7419.JPG
# image path = /content/grav/7419.JPG
# 目が2個検出されました
#
# 197
# 977.JPG
# image path = /content/grav/977.JPG
# 目が2個検出されました
#
# 198
# 965.JPG
# image path = /content/grav/965.JPG
# 目が2個検出されました
#
# 199
# 2762.JPG
# image path = /content/grav/2762.JPG
# 目が2個検出されました
#
# 200
# 2801.jpg
# image path = /content/grav/2801.jpg
# 目が2個検出されました
#
# 201
# 7436.jpg
# image path = /content/grav/7436.jpg
# 目が2個検出されました
#
# 202
# 5015.jpg
# image path = /content/grav/5015.jpg
# 目が2個検出されました
#
# 203
# 2976.jpg
# image path = /content/grav/2976.jpg
# 目が2個検出されました
#
# 204
# 1370.JPG
# image path = /content/grav/1370.JPG
# 目が1個検出されました
#
# 205
# 2523.JPG
# image path = /content/grav/2523.JPG
# 目が2個検出されました
#
# 206
# 6707.JPG
# image path = /content/grav/6707.JPG
# 目が2個検出されました
#
# 207
# 3875.JPG
# image path = /content/grav/3875.JPG
# 目が2個検出されました
#
# 208
# 7867.jpg
# image path = /content/grav/7867.jpg
# 目が2個検出されました
#
# 209
# 7669.JPG
# image path = /content/grav/7669.JPG
# 目が2個検出されました
#
# 210
# 1309.JPG
# image path = /content/grav/1309.JPG
# 目が2個検出されました
#
# 211
# 3532.JPG
# image path = /content/grav/3532.JPG
# 目が2個検出されました
#
# 212
# 7534.JPG
# image path = /content/grav/7534.JPG
# 目が2個検出されました
#
# 213
# 893.jpg
# image path = /content/grav/893.jpg
# 目が2個検出されました
#
# 214
# 957.JPG
# image path = /content/grav/957.JPG
# 目が2個検出されました
#
# 215
# 4759.JPG
# image path = /content/grav/4759.JPG
# 目が2個検出されました
#
# 216
# 502.jpg
# image path = /content/grav/502.jpg
# 目が2個検出されました
#
# 217
# 7765.jpg
# image path = /content/grav/7765.jpg
# 目が2個検出されました
#
# 218
# 6489.JPG
# image path = /content/grav/6489.JPG
# 目が2個検出されました
#
# 219
# 3162.jpg
# image path = /content/grav/3162.jpg
# 目が2個検出されました
#
# 220
# 6502.JPG
# image path = /content/grav/6502.JPG
# 目が2個検出されました
#
# 221
# 4388.JPG
# image path = /content/grav/4388.JPG
# 目が2個検出されました
#
# 222
# 4480.JPG
# image path = /content/grav/4480.JPG
# 目が2個検出されました
#
# 223
# 5607.JPG
# image path = /content/grav/5607.JPG
# 目が2個検出されました
#
# 224
# 2007.JPG
# image path = /content/grav/2007.JPG
# 目が2個検出されました
#
# 225
# 7349.jpg
# image path = /content/grav/7349.jpg
# 目が2個検出されました
#
# 226
# 3528.jpg
# image path = /content/grav/3528.jpg
# 目が2個検出されました
#
# 227
# 5125.jpg
# image path = /content/grav/5125.jpg
# 目が2個検出されました
#
# 228
# 7166.JPG
# image path = /content/grav/7166.JPG
# 目が2個検出されました
#
# 229
# 7346.JPG
# image path = /content/grav/7346.JPG
# 目が2個検出されました
#
# 230
# 1524.jpg
# image path = /content/grav/1524.jpg
# 目が2個検出されました
#
# 231
# 7403.JPG
# image path = /content/grav/7403.JPG
# 目が1個検出されました
#
# 232
# 6579.jpg
# image path = /content/grav/6579.jpg
# 目が2個検出されました
#
# 233
# 17.jpg
# image path = /content/grav/17.jpg
# 目が2個検出されました
#
# 234
# 3472.jpg
# image path = /content/grav/3472.jpg
# 目が2個検出されました
#
# 235
# 6283.JPG
# image path = /content/grav/6283.JPG
# 目が2個検出されました
#
# 236
# 7763.jpg
# image path = /content/grav/7763.jpg
# 目が2個検出されました
#
# 237
# 5297.JPG
# image path = /content/grav/5297.JPG
# 目が2個検出されました
#
# 238
# 6764.jpg
# image path = /content/grav/6764.jpg
# 目が2個検出されました
#
# 239
# 1503.jpg
# image path = /content/grav/1503.jpg
# 目が2個検出されました
#
# 240
# 2684.jpg
# image path = /content/grav/2684.jpg
# 目が2個検出されました
#
# 241
# 1978.jpg
# image path = /content/grav/1978.jpg
# 目が2個検出されました
#
# 242
# 6298.JPG
# image path = /content/grav/6298.JPG
# 目が2個検出されました
#
# 243
# 465.jpg
# image path = /content/grav/465.jpg
# 目が2個検出されました
#
# 244
# 7709.jpg
# image path = /content/grav/7709.jpg
# 目が2個検出されました
#
# 245
# 2370.jpg
# image path = /content/grav/2370.jpg
# 目が2個検出されました
#
# 246
# 5546.jpg
# image path = /content/grav/5546.jpg
# 目が2個検出されました
#
# 247
# 5673.jpg
# image path = /content/grav/5673.jpg
# 目が2個検出されました
#
# 248
# 5582.JPG
# image path = /content/grav/5582.JPG
# 目が2個検出されました
#
# 249
# 1438.jpg
# image path = /content/grav/1438.jpg
# 目が2個検出されました
#
# 250
# 7527.JPG
# image path = /content/grav/7527.JPG
# 目が2個検出されました
#
# 251
# 1333.JPG
# image path = /content/grav/1333.JPG
# 目が2個検出されました
#
# 252
# 1284.jpg
# image path = /content/grav/1284.jpg
# 目が2個検出されました
#
# 253
# 4069.jpg
# image path = /content/grav/4069.jpg
# 目が1個検出されました
#
# 254
# 787.JPG
# image path = /content/grav/787.JPG
# 目が2個検出されました
#
# 255
# 6003.jpg
# image path = /content/grav/6003.jpg
# 目が2個検出されました
#
# 256
# 24.jpg
# image path = /content/grav/24.jpg
# 目が2個検出されました
#
# 257
# 4540.JPG
# image path = /content/grav/4540.JPG
# 目が2個検出されました
#
# 258
# 2557.JPG
# image path = /content/grav/2557.JPG
# 目が2個検出されました
#
# 259
# 4618.JPG
# image path = /content/grav/4618.JPG
# 目が2個検出されました
#
# 260
# 5426.JPG
# image path = /content/grav/5426.JPG
# 目が2個検出されました
#
# 261
# 3568.jpg
# image path = /content/grav/3568.jpg
# 目が2個検出されました
#
# 262
# 3752.JPG
# image path = /content/grav/3752.JPG
# 目が2個検出されました
#
# 263
# 4236.jpg
# image path = /content/grav/4236.jpg
# 目が2個検出されました
#
# 264
# 4813.JPG
# image path = /content/grav/4813.JPG
# 目が2個検出されました
#
# 265
# 122.jpg
# image path = /content/grav/122.jpg
# 目が2個検出されました
#
# 266
# 2231.jpg
# image path = /content/grav/2231.jpg
# 目が2個検出されました
#
# 267
# 2709.jpg
# image path = /content/grav/2709.jpg
# 目が2個検出されました
#
# 268
# 7936.jpg
# image path = /content/grav/7936.jpg
# 目が2個検出されました
#
# 269
# 4881.JPG
# image path = /content/grav/4881.JPG
# 目が2個検出されました
#
# 270
# 534.jpg
# image path = /content/grav/534.jpg
# 目が2個検出されました
#
# 271
# 4465.jpg
# image path = /content/grav/4465.jpg
# 目が1個検出されました
#
# 272
# 7745.JPG
# image path = /content/grav/7745.JPG
# 目が2個検出されました
#
# 273
# 5768.jpg
# image path = /content/grav/5768.jpg
# 目が2個検出されました
#
# 274
# 7283.jpg
# image path = /content/grav/7283.jpg
# 目が2個検出されました
#
# 275
# 1841.jpg
# image path = /content/grav/1841.jpg
# 目が2個検出されました
#
# 276
# 5540.jpg
# image path = /content/grav/5540.jpg
# 目が2個検出されました
#
# 277
# 426.JPG
# image path = /content/grav/426.JPG
# 目が2個検出されました
#
# 278
# 7291.jpg
# image path = /content/grav/7291.jpg
# 目が2個検出されました
#
# 279
# 4209.JPG
# image path = /content/grav/4209.JPG
# 目が2個検出されました
#
# 280
# 6074.JPG
# image path = /content/grav/6074.JPG
# 目が2個検出されました
#
# 281
# 1664.JPG
# image path = /content/grav/1664.JPG
# 目が2個検出されました
#
# 282
# 2203.jpg
# image path = /content/grav/2203.jpg
# 目が2個検出されました
#
# 283
# 1432.JPG
# image path = /content/grav/1432.JPG
# 目が2個検出されました
#
# 284
# 7507.jpg
# image path = /content/grav/7507.jpg
# 目が2個検出されました
#
# 285
# 3942.JPG
# image path = /content/grav/3942.JPG
# 目が2個検出されました
#
# 286
# 2508.jpg
# image path = /content/grav/2508.jpg
# 目が2個検出されました
#
# 287
# 4577.JPG
# image path = /content/grav/4577.JPG
# 目が2個検出されました
#
# 288
# 3809.jpg
# image path = /content/grav/3809.jpg
# 目が2個検出されました
#
# 289
# 7874.JPG
# image path = /content/grav/7874.JPG
# 目が2個検出されました
#
# 290
# 4713.jpg
# image path = /content/grav/4713.jpg
# 目が2個検出されました
#
# 291
# 5543.JPG
# image path = /content/grav/5543.JPG
# 目が2個検出されました
#
# 292
# 3600.jpg
# image path = /content/grav/3600.jpg
# 目が2個検出されました
#
# 293
# 3684.jpg
# image path = /content/grav/3684.jpg
# 目が2個検出されました
#
# 294
# 5646.JPG
# image path = /content/grav/5646.JPG
# 目が2個検出されました
#
# 295
# 5906.jpg
# image path = /content/grav/5906.jpg
# 目が2個検出されました
#
# 296
# 2837.jpg
# image path = /content/grav/2837.jpg
# 目が2個検出されました
#
# 297
# 6269.jpg
# image path = /content/grav/6269.jpg
# 目が2個検出されました
#
# 298
# 6965.jpg
# image path = /content/grav/6965.jpg
# 目が2個検出されました
#
# 299
# 876.jpg
# image path = /content/grav/876.jpg
# 目が2個検出されました
#
# 300
# 1764.JPG
# image path = /content/grav/1764.JPG
# 目が2個検出されました
#
# 301
# 3418.jpg
# image path = /content/grav/3418.jpg
# 目が2個検出されました
#
# 302
# 3264.JPG
# image path = /content/grav/3264.JPG
# 目が2個検出されました
#
# 303
# 5880.JPG
# image path = /content/grav/5880.JPG
# 目が2個検出されました
#
# 304
# 1001.jpg
# image path = /content/grav/1001.jpg
# 目が1個検出されました
#
# 305
# 6486.JPG
# image path = /content/grav/6486.JPG
# 目が2個検出されました
#
# 306
# 5273.JPG
# image path = /content/grav/5273.JPG
# 目が2個検出されました
#
# 307
# 2218.jpg
# image path = /content/grav/2218.jpg
# 目が3個検出されました
#
# 308
# 5299.jpg
# image path = /content/grav/5299.jpg
# 目が2個検出されました
#
# 309
# 983.JPG
# image path = /content/grav/983.JPG
# 目が2個検出されました
#
# 310
# 5069.jpg
# image path = /content/grav/5069.jpg
# 目が2個検出されました
#
# 311
# 1270.jpg
# image path = /content/grav/1270.jpg
# 目が2個検出されました
#
# 312
# 6553.jpg
# image path = /content/grav/6553.jpg
# 目が2個検出されました
#
# 313
# 4874.jpg
# image path = /content/grav/4874.jpg
# 目が2個検出されました
#
# 314
# 466.jpg
# image path = /content/grav/466.jpg
# 目が2個検出されました
#
# 315
# 3046.jpg
# image path = /content/grav/3046.jpg
# 目が2個検出されました
#
# 316
# 2148.jpg
# image path = /content/grav/2148.jpg
# 目が2個検出されました
#
# 317
# 3352.jpg
# image path = /content/grav/3352.jpg
# 目が2個検出されました
#
# 318
# 3237.JPG
# image path = /content/grav/3237.JPG
# 目が2個検出されました
#
# 319
# 1378.JPG
# image path = /content/grav/1378.JPG
# 目が2個検出されました
#
# 320
# 2689.jpg
# image path = /content/grav/2689.jpg
# 目が2個検出されました
#
# 321
# 1336.JPG
# image path = /content/grav/1336.JPG
# 目が2個検出されました
# Process done!!
# elapsed_time:54.283549547195435[sec]
# detection error:
# ['1682.jpg', '6663.jpg', '3144.jpg', '3176.jpg', '5095.JPG', '7025.jpg', '1508.jpg', '1396.jpg', '4292.jpg', '155.jpg', '2218.jpg']

# %%
header = ['Number']

#with open(csv_path, 'w', newline='') as f:  #a:追記モード
with open(csv_path, 'w') as f:
    writer = csv.writer(f)
    writer.writerows(detection_error)

# %% [markdown]
# #切り取られた図を表示してみる

# %%
img_list = os.listdir(out_path)
print(img_list)
img = cv2.imread(out_path +'/'+ file[1])

#アスペクト比を維持したまま横を400pixelに縮小する
def scale_to_width(img, width):
    scale = width / img.shape[1]
    return cv2.resize(img, dsize=None, fx=scale, fy=scale)
dst = scale_to_width(img, 400)

#図を表示する
cv2_imshow(dst)
# Out:
# ['.ipynb_checkpoints', '7534.JPG', '893.jpg', '5125.jpg', '6298.JPG', '957.JPG', '7166.JPG', '4759.JPG', '465.jpg', '7346.JPG', '1524.jpg', '502.jpg', '7709.jpg', '4540.JPG', '7745.JPG', '7403.JPG', '2370.jpg', '7765.jpg', '5768.jpg', '6579.jpg', '6489.JPG', '5546.jpg', '7283.jpg', '2557.JPG', '5673.jpg', '3162.jpg', '17.jpg', '1841.jpg', '4618.JPG', '4577.JPG', '5582.JPG', '6502.JPG', '3472.jpg', '5540.jpg', '3264.JPG', '3352.jpg', '5426.JPG', '1438.jpg', '7867.jpg', '6283.JPG', '426.JPG', '5880.JPG', '4388.JPG', '3237.JPG', '3568.jpg', '7527.JPG', '7874.JPG', '7763.jpg', '7669.JPG', '7291.jpg', '1001.jpg', '4480.JPG', '3752.JPG', '1333.JPG', '5297.JPG', '1309.JPG', '4209.JPG', '4713.jpg', '5607.JPG', '6486.JPG', '6764.jpg', '6074.JPG', '1284.jpg', '3532.JPG', '5543.JPG', '5273.JPG', '1378.JPG', '1503.jpg', '4069.jpg', '3600.jpg', '7349.jpg', '2684.jpg', '2689.jpg', '4236.jpg', '787.JPG', '3684.jpg', '5299.jpg', '1336.JPG', '1664.JPG', '4813.JPG', '983.JPG', '6003.jpg', '5646.JPG', '2203.jpg', '122.jpg', '5906.jpg', '5069.jpg', '1432.JPG', '2231.jpg', '24.jpg', '2837.jpg', '1270.jpg', '7507.jpg', '2709.jpg', '6269.jpg', '6553.jpg', '7936.jpg', '3942.JPG', '6965.jpg', '4874.jpg', '4881.JPG', '466.jpg', '534.jpg', '876.jpg', '3046.jpg', '4465.jpg', '1764.JPG', '2148.jpg', '2508.jpg', '1978.jpg', '3809.jpg', '3528.jpg', '2218.jpg', '2007.JPG', '3695.JPG', '1429.jpg', '1682.jpg', '129.jpg', '3128.jpg', '7798.jpg', '6518.jpg', '5333.jpg', '2182.JPG', '385.jpg', '6320.jpg', '1304.jpg', '374.jpg', '5490.jpg', '818.jpg', '2407.JPG', '489.JPG', '3077.jpg', '3956.JPG', '7443.JPG', '3484.jpg', '3144.jpg', '2658.jpg', '2436.JPG', '5021.JPG', '5692.jpg', '1995.jpg', '3646.jpg', '7049.jpg', '1879.jpg', '2853.jpg', '1786.JPG', '425.jpg', '2974.JPG', '4921.JPG', '1910.JPG', '3609.JPG', '6432.JPG', '6147.jpg', '4272.jpg', '7552.JPG', '2765.JPG', '6663.jpg', '2630.jpg', '1528.JPG', '5758.jpg', '4822.jpg', '2803.jpg', '4186.JPG', '3444.jpg', '1553.jpg', '5323.JPG', '3176.jpg', '7455.JPG', '2736.jpg', '1020.jpg', '4805.jpg', '2042.jpg', '4939.JPG', '5865.JPG', '6662.jpg', '1231.JPG', '2321.jpg', '1088.jpg', '4233.JPG', '3331.JPG', '1453.jpg', '3496.JPG', '1597.JPG', '6150.jpg', '7449.JPG', '36.jpg', '1347.jpg', '4588.jpg', '5095.JPG', '2794.jpg', '1037.jpg', '2960.jpg', '57.jpg', '533.jpg', '6654.jpg', '6725.JPG', '8168.JPG', '2885.JPG', '4486.jpg', '1457.jpg', '4930.JPG', '611.jpg', '2900.jpg', '6513.JPG', '2189.JPG', '1041.JPG', '4710.JPG', '7025.jpg', '2644.jpg', '4997.JPG', '4331.jpg', '4030.jpg', '5989.JPG', '2307.jpg', '3802.jpg', '5070.JPG', '5681.jpg', '8079.JPG', '2941.jpg', '5586.jpg', '4606.jpg', '7397.JPG', '7879.JPG', '5571.JPG', '5838.JPG', '950.JPG', '5763.JPG', '7302.JPG', '1729.JPG', '5647.jpg', '3412.JPG', '3502.jpg', '7161.jpg', '7900.jpg', '3276.JPG', '7681.JPG', '6297.jpg', '4628.JPG', '5378.jpg', '6788.JPG', '5237.JPG', '2222.JPG', '6855.jpg', '1313.JPG', '2851.jpg', '1501.JPG', '180.jpg', '4958.jpg', '1508.jpg', '5965.JPG', '1931.jpg', '5290.JPG', '1357.jpg', '782.JPG', '1259.JPG', '4008.jpg', '5541.jpg', '7781.JPG', '1396.jpg', '1446.JPG', '3164.jpg', '19.jpg', '4125.jpg', '5551.jpg', '555.JPG', '1385.jpg', '718.jpg', '5890.jpg', '429.jpg', '1773.JPG', '4292.jpg', '5913.jpg', '3843.JPG', '3714.jpg', '2670.JPG', '1525.jpg', '7644.JPG', '8184.JPG', '3056.JPG', '3146.JPG', '3079.JPG', '3918.jpg', '7800.JPG', '155.jpg', '5901.jpg', '7987.JPG', '724.JPG', '6355.JPG', '5888.JPG', '6599.jpg', '2510.jpg', '8105.jpg', '5550.jpg', '1483.jpg', '3217.JPG', '507.JPG', '6806.jpg', '4206.jpg', '5260.jpg', '5203.JPG', '7870.jpg', '6555.jpg', '4993.JPG', '1815.JPG', '4382.jpg', '6478.jpg', '7419.JPG', '63.jpg', '977.JPG', '965.JPG', '2762.JPG', '2801.jpg', '7436.jpg', '5015.jpg', '2976.jpg', '1370.JPG', '2523.JPG', '6707.JPG', '3875.JPG', '6989.jpg']
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F2B22794AC8>
