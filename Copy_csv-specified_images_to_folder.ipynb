# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/ImageProcessing/blob/master/Copy_csv-specified_images_to_folder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**CSVから画像番号を抽出し、画像をフォルダにコピーするスクリプト**

# %%
#google driveをcolabolatoryにマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import collections
import os
import shutil

def openCSV(csv_path):
    df = pd.read_csv(csv_path)
    df = df.drop(df.columns[[0]], axis=1) #1列目を削除する
    print(df)
    return df

def getlabel(df):
    img_num = df.iloc[:,0]
    label = df.iloc[:,1]
    class_num = collections.Counter(label)
    return img_num, label, class_num

#CSVを開く （csv1:編集するファイル、csv2:参照するファイル）
csv_path = '/content/drive/My Drive/PrePlusTrain_list.csv'

df = openCSV(csv_path) #CSVを開く
img_num, label, class_num = getlabel(df) #画像番号リストとラベルリストを開く

classes = []
for k in class_num:
    classes.append(k)
print(classes)
# Out:
#      image_name Label  Nakagawa  kitaguchi  inoue  kohzaki  EfficientNet
# 0            17  grav       NaN        NaN    NaN      NaN           NaN
# 1            19  grav       NaN        NaN    NaN      NaN           NaN
# 2            85  cont       NaN        NaN    NaN      NaN           NaN
# 3           129  grav       NaN        NaN    NaN      NaN           NaN
# 4           144  cont       NaN        NaN    NaN      NaN           NaN
# ..          ...   ...       ...        ...    ...      ...           ...
# 553        8149  cont       NaN        NaN    NaN      NaN           NaN
# 554        8168  grav       NaN        NaN    NaN      NaN           NaN
# 555        8184  grav       NaN        NaN    NaN      NaN           NaN
# 556        8198  grav       NaN        NaN    NaN      NaN           NaN
# 557        8210  cont       NaN        NaN    NaN      NaN           NaN
#
# [558 rows x 7 columns]
# ['grav', 'cont']

# %%
def makeFolder(path):
    if not os.path.exists(path):  # ディレクトリがなかったら
        os.mkdir(path)  # 作成したいフォルダ名を作成

#移動先のフォルダを作成
makeFolder("/content/drive/My Drive/PrePlusTrain/558_orig")
#makeFolder("/content/drive/My Drive/PostTrain/oringinal")
for i in classes:
    makeFolder("/content/drive/My Drive/PrePlusTrain/558_orig/"+str(i))  # フォルダ名

#ファイルを移動
k=0
for i in range(len(img_num)):
    dst_path = "/content/drive/My Drive/PrePlusTrain/558_orig/"+str(label[k])+"/"+str(img_num[k])+".jpg"
    org_path = "/content/drive/My Drive/gravcont_orig/"+str(label[k])+"/"+str(img_num[k])+".jpg"
    print(org_path)
    shutil.copy(org_path, dst_path)
    k+=1
# Out:
# /content/drive/My Drive/gravcont_orig/grav/3352.jpg
# /content/drive/My Drive/gravcont_orig/cont/3368.jpg
# /content/drive/My Drive/gravcont_orig/cont/3381.jpg
# /content/drive/My Drive/gravcont_orig/grav/3412.jpg
# /content/drive/My Drive/gravcont_orig/grav/3428.jpg
# /content/drive/My Drive/gravcont_orig/cont/3436.jpg
# /content/drive/My Drive/gravcont_orig/grav/3444.jpg
# /content/drive/My Drive/gravcont_orig/cont/3459.jpg
# /content/drive/My Drive/gravcont_orig/grav/3472.jpg
# /content/drive/My Drive/gravcont_orig/grav/3484.jpg
# /content/drive/My Drive/gravcont_orig/grav/3496.jpg
# /content/drive/My Drive/gravcont_orig/grav/3502.jpg
# /content/drive/My Drive/gravcont_orig/grav/3528.jpg
# /content/drive/My Drive/gravcont_orig/grav/3532.jpg
# /content/drive/My Drive/gravcont_orig/cont/3537.jpg
# /content/drive/My Drive/gravcont_orig/grav/3567.jpg
# /content/drive/My Drive/gravcont_orig/grav/3568.jpg
# /content/drive/My Drive/gravcont_orig/cont/3570.jpg
# /content/drive/My Drive/gravcont_orig/cont/3578.jpg
# /content/drive/My Drive/gravcont_orig/grav/3600.jpg
# /content/drive/My Drive/gravcont_orig/grav/3609.jpg
# /content/drive/My Drive/gravcont_orig/grav/3646.jpg
# /content/drive/My Drive/gravcont_orig/cont/3656.jpg
# /content/drive/My Drive/gravcont_orig/grav/3667.jpg
# /content/drive/My Drive/gravcont_orig/cont/3668.jpg
# /content/drive/My Drive/gravcont_orig/grav/3684.jpg
# /content/drive/My Drive/gravcont_orig/grav/3714.jpg
# /content/drive/My Drive/gravcont_orig/cont/3728.jpg
# /content/drive/My Drive/gravcont_orig/grav/3748.jpg
# /content/drive/My Drive/gravcont_orig/grav/3752.jpg
# /content/drive/My Drive/gravcont_orig/grav/3759.jpg
# /content/drive/My Drive/gravcont_orig/cont/3771.jpg
# /content/drive/My Drive/gravcont_orig/grav/3783.jpg
# /content/drive/My Drive/gravcont_orig/cont/3784.jpg
# /content/drive/My Drive/gravcont_orig/grav/3802.jpg
# /content/drive/My Drive/gravcont_orig/grav/3809.jpg
# /content/drive/My Drive/gravcont_orig/cont/3813.jpg
# /content/drive/My Drive/gravcont_orig/grav/3843.jpg
# /content/drive/My Drive/gravcont_orig/cont/3851.jpg
# /content/drive/My Drive/gravcont_orig/cont/3857.jpg
# /content/drive/My Drive/gravcont_orig/grav/3875.jpg
# /content/drive/My Drive/gravcont_orig/cont/3878.jpg
# /content/drive/My Drive/gravcont_orig/cont/3902.jpg
# /content/drive/My Drive/gravcont_orig/cont/3906.jpg
# /content/drive/My Drive/gravcont_orig/grav/3918.jpg
# /content/drive/My Drive/gravcont_orig/grav/3929.jpg
# /content/drive/My Drive/gravcont_orig/grav/3942.jpg
# /content/drive/My Drive/gravcont_orig/grav/3976.jpg
# /content/drive/My Drive/gravcont_orig/cont/3980.jpg
# /content/drive/My Drive/gravcont_orig/grav/4008.jpg
# /content/drive/My Drive/gravcont_orig/grav/4030.jpg
# /content/drive/My Drive/gravcont_orig/cont/4042.jpg
# /content/drive/My Drive/gravcont_orig/grav/4069.jpg
# /content/drive/My Drive/gravcont_orig/cont/4111.jpg
# /content/drive/My Drive/gravcont_orig/grav/4125.jpg
# /content/drive/My Drive/gravcont_orig/cont/4178.jpg
# /content/drive/My Drive/gravcont_orig/cont/4194.jpg
# /content/drive/My Drive/gravcont_orig/cont/4204.jpg
# /content/drive/My Drive/gravcont_orig/grav/4206.jpg
# /content/drive/My Drive/gravcont_orig/grav/4209.jpg
# /content/drive/My Drive/gravcont_orig/cont/4222.jpg
# /content/drive/My Drive/gravcont_orig/grav/4233.jpg
# /content/drive/My Drive/gravcont_orig/cont/4250.jpg
# /content/drive/My Drive/gravcont_orig/cont/4255.jpg
# /content/drive/My Drive/gravcont_orig/grav/4263.jpg
# /content/drive/My Drive/gravcont_orig/grav/4272.jpg
# /content/drive/My Drive/gravcont_orig/cont/4273.jpg
# /content/drive/My Drive/gravcont_orig/cont/4280.jpg
# /content/drive/My Drive/gravcont_orig/cont/4299.jpg
# /content/drive/My Drive/gravcont_orig/cont/4329.jpg
# /content/drive/My Drive/gravcont_orig/grav/4331.jpg
# /content/drive/My Drive/gravcont_orig/grav/4332.jpg
# /content/drive/My Drive/gravcont_orig/grav/4344.jpg
# /content/drive/My Drive/gravcont_orig/grav/4359.jpg
# /content/drive/My Drive/gravcont_orig/grav/4382.jpg
# /content/drive/My Drive/gravcont_orig/cont/4411.jpg
# /content/drive/My Drive/gravcont_orig/cont/4438.jpg
# /content/drive/My Drive/gravcont_orig/cont/4441.jpg
# /content/drive/My Drive/gravcont_orig/cont/4447.jpg
# /content/drive/My Drive/gravcont_orig/cont/4457.jpg
# /content/drive/My Drive/gravcont_orig/grav/4465.jpg
# /content/drive/My Drive/gravcont_orig/grav/4480.jpg
# /content/drive/My Drive/gravcont_orig/grav/4485.jpg
# /content/drive/My Drive/gravcont_orig/cont/4488.jpg
# /content/drive/My Drive/gravcont_orig/cont/4525.jpg
# /content/drive/My Drive/gravcont_orig/cont/4528.jpg
# /content/drive/My Drive/gravcont_orig/grav/4553.jpg
# /content/drive/My Drive/gravcont_orig/cont/4560.jpg
# /content/drive/My Drive/gravcont_orig/cont/4575.jpg
# /content/drive/My Drive/gravcont_orig/grav/4577.jpg
# /content/drive/My Drive/gravcont_orig/grav/4588.jpg
# /content/drive/My Drive/gravcont_orig/grav/4606.jpg
# /content/drive/My Drive/gravcont_orig/grav/4616.jpg
# /content/drive/My Drive/gravcont_orig/grav/4618.jpg
# /content/drive/My Drive/gravcont_orig/grav/4619.jpg
# /content/drive/My Drive/gravcont_orig/grav/4628.jpg
# /content/drive/My Drive/gravcont_orig/cont/4641.jpg
# /content/drive/My Drive/gravcont_orig/cont/4647.jpg
# /content/drive/My Drive/gravcont_orig/grav/4652.jpg
# /content/drive/My Drive/gravcont_orig/grav/4681.jpg
# /content/drive/My Drive/gravcont_orig/cont/4686.jpg
# /content/drive/My Drive/gravcont_orig/cont/4694.jpg
# /content/drive/My Drive/gravcont_orig/cont/4705.jpg
# /content/drive/My Drive/gravcont_orig/cont/4706.jpg
# /content/drive/My Drive/gravcont_orig/grav/4710.jpg
# /content/drive/My Drive/gravcont_orig/grav/4713.jpg
# /content/drive/My Drive/gravcont_orig/grav/4759.jpg
# /content/drive/My Drive/gravcont_orig/cont/4762.jpg
# /content/drive/My Drive/gravcont_orig/cont/4763.jpg
# /content/drive/My Drive/gravcont_orig/cont/4786.jpg
# /content/drive/My Drive/gravcont_orig/grav/4805.jpg
# /content/drive/My Drive/gravcont_orig/cont/4807.jpg
# /content/drive/My Drive/gravcont_orig/cont/4819.jpg
# /content/drive/My Drive/gravcont_orig/grav/4822.jpg
# /content/drive/My Drive/gravcont_orig/cont/4872.jpg
# /content/drive/My Drive/gravcont_orig/grav/4881.jpg
# /content/drive/My Drive/gravcont_orig/cont/4904.jpg
# /content/drive/My Drive/gravcont_orig/grav/4921.jpg
# /content/drive/My Drive/gravcont_orig/grav/4930.jpg
# /content/drive/My Drive/gravcont_orig/grav/4939.jpg
# /content/drive/My Drive/gravcont_orig/cont/4949.jpg
# /content/drive/My Drive/gravcont_orig/grav/4958.jpg
# /content/drive/My Drive/gravcont_orig/cont/4960.jpg
# /content/drive/My Drive/gravcont_orig/cont/4974.jpg
# /content/drive/My Drive/gravcont_orig/cont/4975.jpg
# /content/drive/My Drive/gravcont_orig/grav/4993.jpg
# /content/drive/My Drive/gravcont_orig/cont/4998.jpg
# /content/drive/My Drive/gravcont_orig/grav/5021.jpg
# /content/drive/My Drive/gravcont_orig/cont/5040.jpg
# /content/drive/My Drive/gravcont_orig/cont/5041.jpg
# /content/drive/My Drive/gravcont_orig/grav/5051.jpg
# /content/drive/My Drive/gravcont_orig/grav/5070.jpg
# /content/drive/My Drive/gravcont_orig/grav/5095.jpg
# /content/drive/My Drive/gravcont_orig/cont/5099.jpg
# /content/drive/My Drive/gravcont_orig/cont/5113.jpg
# /content/drive/My Drive/gravcont_orig/grav/5125.jpg
# /content/drive/My Drive/gravcont_orig/cont/5128.jpg
# /content/drive/My Drive/gravcont_orig/cont/5143.jpg
# /content/drive/My Drive/gravcont_orig/cont/5153.jpg
# /content/drive/My Drive/gravcont_orig/cont/5158.jpg
# /content/drive/My Drive/gravcont_orig/cont/5177.jpg
# /content/drive/My Drive/gravcont_orig/cont/5183.jpg
# /content/drive/My Drive/gravcont_orig/cont/5197.jpg
# /content/drive/My Drive/gravcont_orig/grav/5203.jpg
# /content/drive/My Drive/gravcont_orig/grav/5237.jpg
# /content/drive/My Drive/gravcont_orig/cont/5244.jpg
# /content/drive/My Drive/gravcont_orig/cont/5246.jpg
# /content/drive/My Drive/gravcont_orig/cont/5258.jpg
# /content/drive/My Drive/gravcont_orig/grav/5260.jpg
# /content/drive/My Drive/gravcont_orig/cont/5263.jpg
# /content/drive/My Drive/gravcont_orig/cont/5269.jpg
# /content/drive/My Drive/gravcont_orig/grav/5273.jpg
# /content/drive/My Drive/gravcont_orig/grav/5290.jpg
# /content/drive/My Drive/gravcont_orig/grav/5297.jpg
# /content/drive/My Drive/gravcont_orig/grav/5310.jpg
# /content/drive/My Drive/gravcont_orig/grav/5323.jpg
# /content/drive/My Drive/gravcont_orig/cont/5329.jpg
# /content/drive/My Drive/gravcont_orig/cont/5331.jpg
# /content/drive/My Drive/gravcont_orig/grav/5333.jpg
# /content/drive/My Drive/gravcont_orig/grav/5337.jpg
# /content/drive/My Drive/gravcont_orig/cont/5341.jpg
# /content/drive/My Drive/gravcont_orig/cont/5392.jpg
# /content/drive/My Drive/gravcont_orig/grav/5397.jpg
# /content/drive/My Drive/gravcont_orig/cont/5405.jpg
# /content/drive/My Drive/gravcont_orig/grav/5426.jpg
# /content/drive/My Drive/gravcont_orig/cont/5437.jpg
# /content/drive/My Drive/gravcont_orig/cont/5457.jpg
# /content/drive/My Drive/gravcont_orig/cont/5465.jpg
# /content/drive/My Drive/gravcont_orig/cont/5488.jpg
# /content/drive/My Drive/gravcont_orig/cont/5495.jpg
# /content/drive/My Drive/gravcont_orig/cont/5507.jpg
# /content/drive/My Drive/gravcont_orig/cont/5523.jpg
# /content/drive/My Drive/gravcont_orig/grav/5540.jpg
# /content/drive/My Drive/gravcont_orig/grav/5543.jpg
# /content/drive/My Drive/gravcont_orig/cont/5545.jpg
# /content/drive/My Drive/gravcont_orig/grav/5546.jpg
# /content/drive/My Drive/gravcont_orig/grav/5550.jpg
# /content/drive/My Drive/gravcont_orig/cont/5563.jpg
# /content/drive/My Drive/gravcont_orig/grav/5571.jpg
# /content/drive/My Drive/gravcont_orig/grav/5607.jpg
# /content/drive/My Drive/gravcont_orig/grav/5647.jpg
# /content/drive/My Drive/gravcont_orig/cont/5661.jpg
# /content/drive/My Drive/gravcont_orig/grav/5673.jpg
# /content/drive/My Drive/gravcont_orig/grav/5681.jpg
# /content/drive/My Drive/gravcont_orig/grav/5768.jpg
# /content/drive/My Drive/gravcont_orig/cont/5807.jpg
# /content/drive/My Drive/gravcont_orig/grav/5820.jpg
# /content/drive/My Drive/gravcont_orig/cont/5826.jpg
# /content/drive/My Drive/gravcont_orig/cont/5839.jpg
# /content/drive/My Drive/gravcont_orig/grav/5865.jpg
# /content/drive/My Drive/gravcont_orig/cont/5871.jpg
# /content/drive/My Drive/gravcont_orig/cont/5881.jpg
# /content/drive/My Drive/gravcont_orig/cont/5887.jpg
# /content/drive/My Drive/gravcont_orig/grav/5888.jpg
# /content/drive/My Drive/gravcont_orig/grav/5890.jpg
# /content/drive/My Drive/gravcont_orig/grav/5901.jpg
# /content/drive/My Drive/gravcont_orig/grav/5906.jpg
# /content/drive/My Drive/gravcont_orig/grav/5913.jpg
# /content/drive/My Drive/gravcont_orig/cont/5942.jpg
# /content/drive/My Drive/gravcont_orig/grav/5965.jpg
# /content/drive/My Drive/gravcont_orig/cont/5981.jpg
# /content/drive/My Drive/gravcont_orig/cont/6037.jpg
# /content/drive/My Drive/gravcont_orig/cont/6073.jpg
# /content/drive/My Drive/gravcont_orig/grav/6074.jpg
# /content/drive/My Drive/gravcont_orig/grav/6106.jpg
# /content/drive/My Drive/gravcont_orig/cont/6119.jpg
# /content/drive/My Drive/gravcont_orig/cont/6126.jpg
# /content/drive/My Drive/gravcont_orig/grav/6147.jpg
# /content/drive/My Drive/gravcont_orig/cont/6148.jpg
# /content/drive/My Drive/gravcont_orig/grav/6150.jpg
# /content/drive/My Drive/gravcont_orig/grav/6155.jpg
# /content/drive/My Drive/gravcont_orig/cont/6160.jpg
# /content/drive/My Drive/gravcont_orig/grav/6163.jpg
# /content/drive/My Drive/gravcont_orig/cont/6171.jpg
# /content/drive/My Drive/gravcont_orig/cont/6177.jpg
# /content/drive/My Drive/gravcont_orig/cont/6182.jpg
# /content/drive/My Drive/gravcont_orig/cont/6185.jpg
# /content/drive/My Drive/gravcont_orig/cont/6237.jpg
# /content/drive/My Drive/gravcont_orig/cont/6252.jpg
# /content/drive/My Drive/gravcont_orig/cont/6258.jpg
# /content/drive/My Drive/gravcont_orig/cont/6264.jpg
# /content/drive/My Drive/gravcont_orig/grav/6277.jpg
# /content/drive/My Drive/gravcont_orig/grav/6283.jpg
# /content/drive/My Drive/gravcont_orig/grav/6298.jpg
# /content/drive/My Drive/gravcont_orig/cont/6307.jpg
# /content/drive/My Drive/gravcont_orig/cont/6319.jpg
# /content/drive/My Drive/gravcont_orig/grav/6355.jpg
# /content/drive/My Drive/gravcont_orig/cont/6366.jpg
# /content/drive/My Drive/gravcont_orig/cont/6371.jpg
# /content/drive/My Drive/gravcont_orig/cont/6396.jpg
# /content/drive/My Drive/gravcont_orig/grav/6432.jpg
# /content/drive/My Drive/gravcont_orig/cont/6439.jpg
# /content/drive/My Drive/gravcont_orig/grav/6478.jpg
# /content/drive/My Drive/gravcont_orig/grav/6486.jpg
# /content/drive/My Drive/gravcont_orig/grav/6489.jpg
# /content/drive/My Drive/gravcont_orig/cont/6491.jpg
# /content/drive/My Drive/gravcont_orig/cont/6512.jpg
# /content/drive/My Drive/gravcont_orig/grav/6515.jpg
# /content/drive/My Drive/gravcont_orig/grav/6518.jpg
# /content/drive/My Drive/gravcont_orig/grav/6553.jpg
# /content/drive/My Drive/gravcont_orig/grav/6555.jpg
# /content/drive/My Drive/gravcont_orig/grav/6579.jpg
# /content/drive/My Drive/gravcont_orig/grav/6599.jpg
# /content/drive/My Drive/gravcont_orig/cont/6626.jpg
# /content/drive/My Drive/gravcont_orig/grav/6643.jpg
# /content/drive/My Drive/gravcont_orig/grav/6662.jpg
# /content/drive/My Drive/gravcont_orig/cont/6693.jpg
# /content/drive/My Drive/gravcont_orig/grav/6707.jpg
# /content/drive/My Drive/gravcont_orig/grav/6725.jpg
# /content/drive/My Drive/gravcont_orig/cont/6741.jpg
# /content/drive/My Drive/gravcont_orig/grav/6764.jpg
# /content/drive/My Drive/gravcont_orig/cont/6773.jpg
# /content/drive/My Drive/gravcont_orig/grav/6788.jpg
# /content/drive/My Drive/gravcont_orig/grav/6806.jpg
# /content/drive/My Drive/gravcont_orig/cont/6818.jpg
# /content/drive/My Drive/gravcont_orig/cont/6838.jpg
# /content/drive/My Drive/gravcont_orig/cont/6859.jpg
# /content/drive/My Drive/gravcont_orig/cont/6870.jpg
# /content/drive/My Drive/gravcont_orig/cont/6879.jpg
# /content/drive/My Drive/gravcont_orig/cont/6880.jpg
# /content/drive/My Drive/gravcont_orig/grav/6956.jpg
# /content/drive/My Drive/gravcont_orig/grav/6965.jpg
# /content/drive/My Drive/gravcont_orig/grav/6989.jpg
