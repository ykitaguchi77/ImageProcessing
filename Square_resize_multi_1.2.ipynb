# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/ImageProcessing/blob/master/Square_resize_multi_1.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Square_resize_multi_250pix
#
# 長方形を、長辺を一辺とした正方形にresizeし余白を黒く塗りつぶした上で、250pixに縮小するスクリプト

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import copy
import pandas as pd
import csv
from random import randint
from time import sleep
import math

import glob
import random
from PIL import Image
# %matplotlib inline

#サポートパッチのインポート
from google.colab.patches import cv2_imshow
import cv2

plt.ion()   # interactive mode

#Google driveをマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #保存あり

# %%
def convert(in_path, out_path):
    #処理時間の計測
    start = time.time()

    l=0
    for i in processing_file:      
          img = Image.open(in_path + '/' + i)
          img_new = expand2square(img, (0, 0, 0)).resize((250, 250))
          img_new.save(out_path +'/'+ i)
          print(out_path +'/'+ i)
          
          #切り取った画像を表示
          #plt.imshow(np.asarray(img_new))
          #plt.show()

    print('Process done!!')
    elapsed_time = time.time() - start
    print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")

def expand2square(pil_img, background_color):
    width, height = pil_img.size
    if width == height:
        return pil_img
    elif width > height:
        result = Image.new(pil_img.mode, (width, width), background_color)
        result.paste(pil_img, (0, (width-height)//2))
        return result
    else:
        result = Image.new(pil_img.mode, (height, height), background_color)
        result.paste(pil_img, (0, (height - width) // 2))
        return result

def showInfo(in_path):
    #処理するDirectoryの設定
    file = os.listdir(in_path)
    print(len(file))

    #ここにフォルダ番号を記載する (ex. [0:999])
    processing_file = file[0:999]
    print(processing_file)
    len(processing_file)

# %%
#元画像フォルダ
in_path = '/content/drive/My Drive/Deep_learning/grav_add'

#保存先フォルダ
out_path = '/content/drive/My Drive/Deep_learning/gravcont_processed2/grav'
if not os.path.exists(out_path):
    os.makedirs(out_path)

showInfo(in_path)
convert(in_path, out_path)

#元画像フォルダ
in_path = '/content/drive/My Drive/Deep_learning/cont_add'

#保存先フォルダ
out_path = '/content/drive/My Drive/Deep_learning/gravcont_processed2/cont'
if not os.path.exists(out_path):
    os.makedirs(out_path)

showInfo(in_path)
convert(in_path, out_path)
# Out:
# 333
# ['2853.jpg', '5015.jpg', '4681.jpg', '2644.jpg', '2900.jpg', '1503.jpg', '2851.jpg', '6599.jpg', '4486.jpg', '5673.jpg', '6965.jpg', '2042.jpg', '7077.jpg', '2960.jpg', '429.jpg', '3759.jpg', '4008.jpg', '5890.jpg', '6106.jpg', '4805.jpg', '6855.jpg', '533.jpg', '1347.jpg', '1357.jpg', '4465.jpg', '6579.jpg', '6518.jpg', '1525.jpg', '4606.jpg', '2684.jpg', '6147.jpg', '466.jpg', '4713.jpg', '3600.jpg', '4332.jpg', '2630.jpg', '7936.jpg', '5820.jpg', '6150.jpg', '1385.jpg', '1931.jpg', '5260.jpg', '5550.jpg', '7428.jpg', '3144.jpg', '2231.jpg', '374.jpg', '3164.jpg', '3162.jpg', '3748.jpg', '4206.jpg', '1453.jpg', '5758.jpg', '2726.jpg', '1841.jpg', '1438.jpg', '6555.jpg', '893.jpg', '4272.jpg', '1270.jpg', '7049.jpg', '7765.jpg', '465.jpg', '3802.jpg', '1020.jpg', '1682.jpg', '4331.jpg', '4030.jpg', '6764.jpg', '6806.jpg', '180.jpg', '3444.jpg',
4881.JPG', '4921.JPG', '4930.JPG', '4939.JPG', '4997.JPG', '4993.JPG', '5021.JPG', '5070.JPG', '5095.JPG', '5203.JPG', '5237.JPG', '5273.JPG', '5290.JPG', '5297.JPG', '5323.JPG', '5426.JPG', '5543.JPG', '5571.JPG', '5607.JPG', '5646.JPG', '5763.JPG', '5838.JPG', '5865.JPG', '5888.JPG', '5965.JPG', '5989.JPG', '6074.JPG', '6283.JPG', '6298.JPG', '6355.JPG', '6432.JPG', '6486.JPG', '6489.JPG', '6502.JPG', '6513.JPG', '6707.JPG', '6725.JPG', '6788.JPG', '6956.JPG', '7166.JPG', '7302.JPG', '7346.JPG', '7403.JPG', '7419.JPG', '7443.JPG', '7449.JPG', '7455.JPG', '7527.JPG', '7534.JPG', '7552.JPG', '7644.JPG', '7669.JPG', '7681.JPG', '7745.JPG', '7781.JPG', '7800.JPG', '7874.JPG', '7879.JPG', '8079.JPG', '8168.JPG', '8184.JPG']
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2853.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5015.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4681.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2644.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2900.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1503.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2851.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6599.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4486.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5673.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6965.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2042.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7077.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2960.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/429.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3759.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4008.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5890.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6106.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4805.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6855.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/533.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1347.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1357.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4465.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6579.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6518.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1525.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4606.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2684.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6147.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/466.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4713.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3600.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4332.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2630.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7936.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5820.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6150.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1385.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1931.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5260.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5550.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7428.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3144.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2231.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/374.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3164.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3162.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3748.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4206.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1453.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5758.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2726.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1841.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1438.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6555.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/893.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4272.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1270.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7049.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7765.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/465.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3802.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1020.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1682.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4331.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4030.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6764.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6806.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/180.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3444.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/8198.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2668.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3918.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2148.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1396.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7291.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2709.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6662.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/876.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3568.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3128.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3484.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7295.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2803.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5768.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3209.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6989.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5397.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/718.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5125.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7709.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5333.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5335.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6478.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3684.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5299.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2664.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2321.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4069.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1524.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4958.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3472.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7798.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7349.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5608.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6515.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7763.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1037.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7041.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5378.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/611.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4822.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3809.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1457.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7867.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/129.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4292.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5540.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5051.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5546.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3502.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1088.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4263.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/534.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4652.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6003.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4485.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5310.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2414.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6155.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6553.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7900.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3567.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4588.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5913.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2967.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5337.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1001.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6643.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1429.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3077.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6163.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5906.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3714.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5069.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3543.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1284.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/818.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3176.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2370.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5647.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7104.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1913.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1995.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4382.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2307.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2794.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/1553.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/19.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2689.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3646.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/2837.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7283.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3783.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3352.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4125.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7277.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/4619.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5586.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/7436.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/6297.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/3046.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/5901.jpg
# /content/drive/My Drive/Deep_learning/gravcont_processed2/grav/155.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-c4bf847a0a07> in <module>()
#       8
#       9 showInfo(in_path)
# ---> 10 convert(in_path, out_path)
#      11
#      12 #元画像フォルダ
#
# <ipython-input-22-33e1a3046f32> in convert(in_path, out_path)
#       6     for i in processing_file:
#       7           img = Image.open(in_path + '/' + i)
# ----> 8           img_new = expand2square(img, (0, 0, 0)).resize((250, 250))
#       9           img_new.save(out_path +'/'+ i)
#      10           print(out_path +'/'+ i)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1871                 )
#    1872
# -> 1873         return self._new(self.im.resize(size, resample, box))
#    1874
#    1875     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 444, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 408, in execute_request
#     time.sleep(self._execute_sleep)
# KeyboardInterrupt
